# %%
import mne
import matplotlib.pyplot as plt
import numpy as np

# %%
edf_file = "D:/M.Tech/3rd Sem/trials/Dataset comparision/Motor/S001/S001R01.edf"
raw = mne.io.read_raw_edf(edf_file, preload=True)
# Out:
# Extracting EDF parameters from D:/M.Tech/3rd Sem/trials/Dataset comparision/Motor/S001/S001R01.edf...
# Setting channel info structure...
# Creating raw.info structure...
# Reading 0 ... 9759  =      0.000 ...    60.994 secs...

# %%
rename_dict = {ch: ch.replace('.', '') for ch in raw.ch_names}
raw.rename_channels(rename_dict)
# Out:
# <RawEDF | S001R01.edf, 64 x 9760 (61.0 s), ~4.8 MiB, data loaded>

# %%
print("\nOriginal Channel Names:")
print(raw.ch_names)
# Out:
# Original Channel Names:
# ['Fc5', 'Fc3', 'Fc1', 'Fcz', 'Fc2', 'Fc4', 'Fc6', 'C5', 'C3', 'C1', 'Cz', 'C2', 'C4', 'C6', 'Cp5', 'Cp3', 'Cp1', 'Cpz', 'Cp2', 'Cp4', 'Cp6', 'Fp1', 'Fpz', 'Fp2', 'Af7', 'Af3', 'Afz', 'Af4', 'Af8', 'F7', 'F5', 'F3', 'F1', 'Fz', 'F2', 'F4', 'F6', 'F8', 'Ft7', 'Ft8', 'T7', 'T8', 'T9', 'T10', 'Tp7', 'Tp8', 'P7', 'P5', 'P3', 'P1', 'Pz', 'P2', 'P4', 'P6', 'P8', 'Po7', 'Po3', 'Poz', 'Po4', 'Po8', 'O1', 'Oz', 'O2', 'Iz']

# %%
channel_names = [
    'Fp1','Fp2',
    'F7','F3','Fz','F4','F8',
    'T7','C3','Cz','C4','T8',
    'P7','P3','Pz','P4','P8',
    'O1','O2'
]
raw.pick(channel_names)
# Out:
# <RawEDF | S001R01.edf, 19 x 9760 (61.0 s), ~1.4 MiB, data loaded>

# %%
montage = mne.channels.make_standard_montage("standard_1020")
raw.set_montage(montage)
# Out:
# <RawEDF | S001R01.edf, 19 x 9760 (61.0 s), ~1.4 MiB, data loaded>

# %%
raw.set_eeg_reference(ref_channels=['Cz'])
# Out:
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# <RawEDF | S001R01.edf, 19 x 9760 (61.0 s), ~1.4 MiB, data loaded>

# %%
raw.plot_sensors(kind='topomap', show_names=True)

plt.show()
